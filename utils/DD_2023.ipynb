# %% [markdown]
# # INF - MINI 2023

# %%
inf_mini = 'C:/Users/emita/Bootcamp/REPO PROFE/COPIA REPO/repo-clase-dsvlcsep24/EDA/PAGOS_POR_CAT/INF_MINI_2023.csv'

# %%
cat_inf_mini = pd.read_csv(inf_mini)

# %%
cat_inf_mini=cat_inf_mini.drop(columns=["NOV", "DIC", "Unnamed: 16"])

# %%
cat_inf_mini=cat_inf_mini.iloc[:32,:]

# %%
cat_inf_mini.loc[:, 'FEB':'OCT'] = cat_inf_mini.loc[:, 'FEB':'OCT'].apply(fill_na_no_inscripto, axis=1)

# %%
cat_inf_mini.loc[:, 'FEB':'OCT'] = cat_inf_mini.loc[:, 'FEB':'OCT'].apply(fill_nan_baja, axis=1)

# %%
cat_inf_mini.loc[:, 'FEB':'OCT'] = cat_inf_mini.loc[:, 'FEB':'OCT'].apply(fill_nan_beca, axis=1)

# %%
cat_inf_mini
# Out:
#      CATEGORIA          APELLIDO                 NOMBRE SEGURO           FEB  \
# 0         MINI           Acevedo     Cristobal Giovanni     NO             X
# 1   INFANTILES         Aqueveque                   Aron     NO             X
# 2         MINI          Alvarez              Maria Pia      NO             X
# 3         MINI          Bichara           Gonzalo Farid     NO             X
# 4         MINI           Briones              Francisco     SI             X
# 5   INFANTILES           Bustos                   Alma      SI             X
# 6   INFANTILES           Cabrera                German      SI  No inscripto
# 7         MINI           Campos          Thiago Ignacio     SI  No inscripto
# 8         MINI         Castillo               Santiago      NO  No inscripto
# 9         MINI            Colipe        Fabricio Martin     SI             X
# 10        MINI           Colussi              Valentino     SI  No inscripto
# ...

# %%
cat_inf_mini["DATOS"] = cat_inf_mini["DATOS"].fillna("No")

# %%
cat_inf_mini["SEGURO"] = cat_inf_mini["SEGURO"].fillna("No")

# %%
cat_inf_mini.isna().values.any()
# Out:
# np.False_
